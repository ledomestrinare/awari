# %%
#bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['figure.figsize'] = (16,8)

# %%
#dados
url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.433/dados?formato=json'

# %%
df = pd.read_json(url)

# %%
sns.barplot(df.data, df.valor, color='blue');
